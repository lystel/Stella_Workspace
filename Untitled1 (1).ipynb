# %%
import cv2
from PIL import Image


img1 = cv2.imread('80.jpg')
img2 = cv2.imread('90.jpg')
dst = cv2.addWeighted(img1,0.5,img2,0.5,0)
#cv2.imshow('dst',dst)
display(Image.fromarray(dst))

# %%
from PIL import Image
import numpy as np
from pynq import allocate, Overlay
import math, time
from ipywidgets import fixed, interact_manual
import ipywidgets as widgets
import matplotlib.pyplot as plt
import pandas as pd

# %%
overlay = Overlay("addWeighted.bit")
regs = overlay.addweighted_0.register_map

im1 = Image.open("80.jpg")
display(im1)
im2 = Image.open("90.jpg")
display(im2)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-2-98b92e19f1d0> in <module>()
#       1 overlay = Overlay("addWeighted.bit")
# ----> 2 regs = overlay.addweighted_0.register_map
#       3
#       4 im1 = Image.open("80.jpg")
#       5 display(im1)
#
# /usr/local/lib/python3.6/dist-packages/pynq/overlay.py in register_map(self)
#     744                 self._register_map = RegisterMap.create_subclass(
#     745                     self._register_name,
# --> 746                     self._registers)(self.mmio.array)
#     747             else:
#     748                 raise AttributeError(
#
# /usr/local/lib/python3.6/dist-packages/pynq/registers.py in __init__(self, buffer)
#     395                 continue
#     396             self._instances[k] = v[0](
# --> 397                 address=v[1], width=align_width, buffer=array)
#     398
# ...

# %%
out_size = im1.shape

buf_in1 = allocate(shape=(im1.shape), 
                            dtype=np.uint8, cacheable=1)
buf_in1[:] = np.array(im1)
buf_in2 = allocate(shape=(im2.shape), 
                            dtype=np.uint8, cacheable=1)
buf_in2[:] = np.array(im2)
buf_out = allocate(shape=(im1.shape), 
                            dtype=np.uint8, cacheable=1)

regs.img_in1 = buf_in1.device_address
regs.img_in2 = buf_in2.device_address
regs.img_out = buf_out.device_address
regs.rows_in, regs.cols_in = im1.size
regs.alpha, regs.beta, regs.gamma = 0.5,0.5,0

# %%
regs.CTRL.AUTO_RESTART = 1
regs.CTRL.AP_START = 1

while regs.CTRL.AP_DONE == 0:
    pass

im_out = Image.fromarray(buf_out)
display(im_out)
